# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv("covid_pa_confirmed_data_7d.csv")
data.value = data.value.astype(int)
data
# Out:
#      Unnamed: 0 geo_value                        signal  time_value  \
# 0             0        pa  confirmed_7dav_incidence_num  2020-02-20
# 1             0        pa  confirmed_7dav_incidence_num  2020-02-21
# 2             0        pa  confirmed_7dav_incidence_num  2020-02-22
# 3             0        pa  confirmed_7dav_incidence_num  2020-02-23
# 4             0        pa  confirmed_7dav_incidence_num  2020-02-24
# ..          ...       ...                           ...         ...
# 835           0        pa  confirmed_7dav_incidence_num  2022-06-04
# 836           0        pa  confirmed_7dav_incidence_num  2022-06-05
# 837           0        pa  confirmed_7dav_incidence_num  2022-06-06
# 838           0        pa  confirmed_7dav_incidence_num  2022-06-07
# 839           0        pa  confirmed_7dav_incidence_num  2022-06-08
#
#           issue  lag  missing_value  missing_stderr  missing_sample_size  \
# 0    2021-04-01  406              0               0                    0
# ...

# %%
def bootstrap(data, space ,overlap):
    bootstrap_data = []
    i = 0
    while i < len(data):
        bootstrap_data.append(data[i+space-overlap:i+space].mean())
        i = i+space
    return bootstrap_data
bootstrap_data = bootstrap(data.value, space = 2, overlap = 1)
print(len(data.value),len(bootstrap_data))
# Out:
# 840 420

# %%
bootstrap_data

# %%
data.value
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 835    3551
# 836    3551
# 837    3883
# 838    3883
# 839    3223
# Name: value, Length: 840, dtype: int64
