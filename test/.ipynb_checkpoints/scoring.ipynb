# %%
import chimeric_tools.Simulation as ctc
import chimeric_tools.Data as ctd
import chimeric_tools.models as ctm
from datetime import date
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
plt.rc("figure", figsize=(16, 6))
plt.rc("savefig", dpi=90)
plt.rc("font", family="sans-serif")
plt.rc("font", size=14)

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [7], line 3
#       1 import chimeric_tools.Simulation as ctc
#       2 import chimeric_tools.Data as ctd
# ----> 3 import chimeric_tools.models as ctm
#       4 from datetime import date
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~/Desktop/ra/chimeric-tools/src/chimeric_tools/models.py:18
#      16 from xgboost import XGBRegressor
#      17 # from lightgbm import LGBMRegressor
# ---> 18 from catboost import CatBoostRegressor
#      19 from prophet.diagnostics import cross_validation
#      20 from prophet.diagnostics import performance_metrics
#
# ModuleNotFoundError: No module named 'catboost'

# %%
bs = ctc.COVID(start_date="2020-01-01", end_date="2021-07-31", geo_values=["US", "42095"], include=["cases"]).simulate("auto", 5)
# preds = ctm.train_simulated_data(bs, ["AR3", "AR6", "ridge"], target="cases")
# Out:
# /Users/vincent/Desktop/ra/chimeric-tools/src/chimeric_tools/Data.py:109: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(stream, compression="gzip")
# /Users/vincent/Desktop/ra/chimeric-tools/src/chimeric_tools/Data.py:296: UserWarning: start_date is before the earliest date in the data. Now using default start date
#   warnings.warn(

# %%
bs
# Out:
#            date    end_date location       location_name      EW  sim  \
# 0    2020-01-19  2020-01-25       US       United States  202004    0
# 1    2020-01-26  2020-02-01       US       United States  202005    0
# 2    2020-02-02  2020-02-08       US       United States  202006    0
# 3    2020-02-09  2020-02-15       US       United States  202007    0
# 4    2020-02-16  2020-02-22       US       United States  202008    0
# ..          ...         ...      ...                 ...     ...  ...
# 395  2021-06-27  2021-07-03    42095  Northampton County  202126    4
# 396  2021-07-04  2021-07-10    42095  Northampton County  202127    4
# 397  2021-07-11  2021-07-17    42095  Northampton County  202128    4
# 398  2021-07-18  2021-07-24    42095  Northampton County  202129    4
# 399  2021-07-25  2021-07-31    42095  Northampton County  202130    4
#
#             cases
# 0   -19270.244101
# 1    13838.483080
# 2    -6665.755237
# 3   -54245.765818
# 4     9931.033862
# ..            ...
# 395      5.504638
# 396    147.559479
# 397    260.077929
# 398    213.505231
# 399    502.276266
#
# [400 rows x 7 columns]
